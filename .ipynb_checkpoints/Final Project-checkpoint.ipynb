# %%
# !pip3 install html5lib
import requests
from bs4 import BeautifulSoup
import pandas as pd
# !pip3 install sodapy
from sodapy import Socrata
# Out:
# Requirement already satisfied: html5lib in /opt/conda/lib/python3.8/site-packages (1.1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.8/site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in /opt/conda/lib/python3.8/site-packages (from html5lib) (1.15.0)
# Requirement already satisfied: sodapy in /opt/conda/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: requests>=2.20.0 in /opt/conda/lib/python3.8/site-packages (from sodapy) (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=2.20.0->sodapy) (1.25.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests>=2.20.0->sodapy) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=2.20.0->sodapy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests>=2.20.0->sodapy) (3.0.4)

# %%
#data collection
#we can access the dataset via the SODA API
#since the dataset has too many rows, we will only process the first 100 thousand rows.
client = Socrata("data.montgomerycountymd.gov", None)
results = client.get("4mse-ku6q",limit=50000)
df = pd.DataFrame.from_records(results)
df.head()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#                                  seq_id             date_of_stop time_of_stop  \
# 0  21e79433-7ba0-445a-80b0-26b6843e1897  2020-11-17T00:00:00.000     22:00:00
# 1  21e79433-7ba0-445a-80b0-26b6843e1897  2020-11-17T00:00:00.000     22:00:00
# 2  13fad11b-6ab4-4ef9-b7fd-1de4ffc45761  2020-11-17T00:00:00.000     21:54:00
# 3  13fad11b-6ab4-4ef9-b7fd-1de4ffc45761  2020-11-17T00:00:00.000     21:54:00
# 4  13fad11b-6ab4-4ef9-b7fd-1de4ffc45761  2020-11-17T00:00:00.000     21:54:00
#
#   agency                 subagency  \
# 0    MCP   1st District, Rockville
# 1    MCP   1st District, Rockville
# 2    MCP  5th District, Germantown
# 3    MCP  5th District, Germantown
# 4    MCP  5th District, Germantown
#
#                                          description  \
# 0  FAILURE TO DISPLAY REGISTRATION CARD UPON DEMA...
# 1  FAILURE TO DISPLAY TWO LIGHTED FRONT LAMPS WHE...
# 2  DRIVING VEHICLE ON HIGHWAY WITHOUT CURRENT REG...
# 3  FAILURE TO ATTACH VEHICLE REGISTRATION PLATES ...
# 4  FAILURE TO DISPLAY REGISTRATION CARD UPON DEMA...
#
#                                 location          latitude          longitude  \
# 0          MONTROSE PKWY AND MONTROSE RD  39.0530166666667  -77.1358126666667
# 1          MONTROSE PKWY AND MONTROSE RD  39.0530166666667  -77.1358126666667
# 2  GERMANTOWN RD / KINGSVIEW VILLAGE AVE  39.1605683333333  -77.2800216666667
# 3  GERMANTOWN RD / KINGSVIEW VILLAGE AVE  39.1605683333333  -77.2800216666667
# 4  GERMANTOWN RD / KINGSVIEW VILLAGE AVE  39.1605683333333  -77.2800216666667
#
#   accident  ... :@computed_region_kbsp_ykn9 :@computed_region_d7bw_bq6x  \
# 0       No  ...                          19                          60
# 1      Yes  ...                          19                          60
# 2       No  ...                          39                          39
# 3       No  ...                          39                          39
# 4       No  ...                          39                          39
#
#   :@computed_region_rbt8_3x7n search_conducted search_outcome  \
# 0                           1              NaN            NaN
# 1                           1              NaN            NaN
# 2                           1              NaN            NaN
# 3                           1              NaN            NaN
# 4                           1              NaN            NaN
#
#   search_reason_for_stop search_disposition search_reason search_type  \
# 0                    NaN                NaN           NaN         NaN
# 1                    NaN                NaN           NaN         NaN
# 2                    NaN                NaN           NaN         NaN
# 3                    NaN                NaN           NaN         NaN
# 4                    NaN                NaN           NaN         NaN
#
#   search_arrest_reason
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 48 columns]

# %%
#data processing
#dont need some of these columns so we can drop them
df = df.drop(['color','vehicle_type','hazmat','work_zone','alcohol','commercial_vehicle','commercial_license'],axis = 1)
df = df.drop(['property_damage','model','search_outcome','search_reason_for_stop','search_conducted','contributed_to_accident'],axis = 1)
df = df.drop(['fatal','accident','belts','personal_injury','article','driver_state','dl_state',':@computed_region_vu5j_pcmz',':@computed_region_rbt8_3x7n'],axis = 1)
df = df.drop([':@computed_region_kbsp_ykn9',':@computed_region_tx5f_5em3','geolocation','seq_id','agency','latitude'], axis = 1)
df = df.drop(['longitude',':@computed_region_d7bw_bq6x','search_disposition','search_reason','search_type','search_arrest_reason'],axis = 1)
df
# Out:
#                   date_of_stop time_of_stop                    subagency  \
# 0      2020-11-17T00:00:00.000     22:00:00      1st District, Rockville
# 1      2020-11-17T00:00:00.000     22:00:00      1st District, Rockville
# 2      2020-11-17T00:00:00.000     21:54:00     5th District, Germantown
# 3      2020-11-17T00:00:00.000     21:54:00     5th District, Germantown
# 4      2020-11-17T00:00:00.000     21:54:00     5th District, Germantown
# ...                        ...          ...                          ...
# 49995  2020-01-29T00:00:00.000     16:26:00        4th District, Wheaton
# 49996  2020-01-29T00:00:00.000     16:21:00       2nd District, Bethesda
# 49997  2020-01-29T00:00:00.000     16:21:00       2nd District, Bethesda
# 49998  2020-01-29T00:00:00.000     16:21:00       2nd District, Bethesda
# 49999  2020-01-29T00:00:00.000     16:18:00  3rd District, Silver Spring
#
#                                              description  \
# 0      FAILURE TO DISPLAY REGISTRATION CARD UPON DEMA...
# 1      FAILURE TO DISPLAY TWO LIGHTED FRONT LAMPS WHE...
# 2      DRIVING VEHICLE ON HIGHWAY WITHOUT CURRENT REG...
# 3      FAILURE TO ATTACH VEHICLE REGISTRATION PLATES ...
# 4      FAILURE TO DISPLAY REGISTRATION CARD UPON DEMA...
# ...                                                  ...
# 49995  UNAUTHORIZED DISPLAY AND USE OF REGISTRATION P...
# 49996  DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC...
# 49997                       FAILURE TO STOP AT STOP SIGN
# 49998                                    STOP LIGHTS (*)
# 49999  DRIVER USING HANDS TO USE HANDHELD TELEPHONE W...
#
#                                     location state  year    make  \
# 0              MONTROSE PKWY AND MONTROSE RD    MD  2009  TOYTOA
# 1              MONTROSE PKWY AND MONTROSE RD    MD  2009  TOYTOA
# 2      GERMANTOWN RD / KINGSVIEW VILLAGE AVE    XX  2007    JEEP
# 3      GERMANTOWN RD / KINGSVIEW VILLAGE AVE    XX  2007    JEEP
# 4      GERMANTOWN RD / KINGSVIEW VILLAGE AVE    XX  2007    JEEP
# ...                                      ...   ...   ...     ...
# 49995                      LAYHILL RD/MD 200    MD  2016    FORD
# 49996                   ST PAUL ST@OBERON ST    MD  2006    CHEV
# 49997                   ST PAUL ST@OBERON ST    MD  2006    CHEV
# 49998                   ST PAUL ST@OBERON ST    MD  2006    CHEV
# 49999      NB MCKNEW RD @ SADDLE CREEK DRIVE    MD  2017   HONDA
#
#       violation_type         charge      race gender   driver_city  \
# 0            Warning      13-409(b)     WHITE      F    GERMANTOWN
# 1            Warning      22-226(a)     WHITE      F    GERMANTOWN
# 2           Citation      13-411(d)     BLACK      M    CLARKSBURG
# 3           Citation      13-411(a)     BLACK      M    CLARKSBURG
# 4            Warning      13-409(b)     BLACK      M    CLARKSBURG
# ...              ...            ...       ...    ...           ...
# 49995        Warning      13-703(g)     WHITE      M  SPENCERVILLE
# 49996        Warning     21-201(a1)  HISPANIC      M  GAITHERSBURG
# 49997        Warning      21-707(a)  HISPANIC      M  GAITHERSBURG
# 49998          ESERO            64*  HISPANIC      M  GAITHERSBURG
# 49999        Warning  21-1124.2(d2)     BLACK      F  BURTONSVILLE
#
#                  arrest_type
# 0          A - Marked Patrol
# 1          A - Marked Patrol
# 2          A - Marked Patrol
# 3          A - Marked Patrol
# 4          A - Marked Patrol
# ...                      ...
# 49995      A - Marked Patrol
# 49996  M - Marked (Off-Duty)
# 49997  M - Marked (Off-Duty)
# 49998  M - Marked (Off-Duty)
# 49999      A - Marked Patrol
#
# [50000 rows x 14 columns]

# %%
#some of the charge meaning
#21-801 = speed charge
#13-409 = FAILURE TO DISPLAY REGISTRATION CARD UPON DEMAND BY POLICE OFFICER
#21-20 = DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC CONTROL DEVICE INSTRUCTIONS
#21-1124 = Reckless driving(texting and driving)
#21-201 = DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC CONTROL DEVICE INSTRUCTIONS
#13-411 = DISPLAYING EXPIRED REGISTRATION PLATE ISSUED BY ANY STATE
